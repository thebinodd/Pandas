# %%
import pandas as pd

# %%
data = pd.read_csv("ipl.csv")

# %%
cities = data.groupby("city") #make a group on the basis of cities

# %%
cities.size().sort_values(ascending=False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Ranchi             7
# Cuttack            7
# Abu Dhabi          7
# Port Elizabeth     7
# Cape Town          7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# dtype: int64

# %%
cities.get_group("Kolkata")
# Out:
#       id  season     city        date                    team1  \
# 10    11    2017  Kolkata  2017-04-13          Kings XI Punjab
# 13    14    2017  Kolkata  2017-04-15    Kolkata Knight Riders
# 22    23    2017  Kolkata  2017-04-21    Kolkata Knight Riders
# 26    27    2017  Kolkata  2017-04-23    Kolkata Knight Riders
# 30    31    2017  Kolkata  2017-04-28         Delhi Daredevils
# ..   ...     ...      ...         ...                      ...
# 607  608    2016  Kolkata  2016-05-04    Kolkata Knight Riders
# 613  614    2016  Kolkata  2016-05-08    Kolkata Knight Riders
# 620  621    2016  Kolkata  2016-05-14  Rising Pune Supergiants
# 623  624    2016  Kolkata  2016-05-16    Kolkata Knight Riders
# 630  631    2016  Kolkata  2016-05-22    Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 10         Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
cities["win_by_runs"].mean().sort_values(ascending=False)
# Out:
# city
# Dharamsala        31.000000
# East London       29.000000
# Port Elizabeth    28.571429
# Visakhapatnam     25.636364
# Abu Dhabi         22.428571
# Kochi             22.000000
# Cape Town         20.714286
# Bangalore         19.136364
# Kimberley         17.666667
# Pune              17.031250
# Ahmedabad         15.000000
# Chennai           14.895833
# Delhi             14.600000
# Jaipur            13.939394
# Mumbai            12.964706
# Chandigarh        12.521739
# Sharjah           12.333333
# Durban            10.600000
# Cuttack           10.428571
# Hyderabad          9.918367
# Kolkata            9.622951
# Bloemfontein       7.000000
# Rajkot             7.000000
# Centurion          6.750000
# Ranchi             5.857143
# Nagpur             5.000000
# Raipur             3.500000
# Johannesburg       3.125000
# Indore             0.000000
# Kanpur             0.000000
# Name: win_by_runs, dtype: float64
