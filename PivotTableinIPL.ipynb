# %%
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("deliveries.csv")

# %%
mask = data["batsman_runs"] == 6
sixes = data[mask]

# %%
pt = sixes.pivot_table(index="over" , columns = "batting_team" , values="batsman_runs" , aggfunc = "count")
pt
#gives the table showing total sixes by ipl team in each over
# Out:
# batting_team  Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# over
# 1                             5.0              3.0              14.0
# 2                            17.0             21.0              19.0
# 3                            37.0             11.0              30.0
# 4                            34.0             17.0              41.0
# 5                            41.0             27.0              29.0
# 6                            43.0             22.0              27.0
# 7                            22.0             11.0              20.0
# 8                            25.0             13.0              26.0
# 9                            23.0             17.0              32.0
# 10                           23.0             14.0              24.0
# 11                           36.0             15.0              34.0
# 12                           36.0             26.0              38.0
# ...

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='batting_team', ylabel='over'>
