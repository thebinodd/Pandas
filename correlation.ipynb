# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("tips.csv")

# %%
df = data.corr(numeric_only="True")

#Same value , correlation = 0
# Higher the Correlation, higher the relation among them
#Negative Correlation -> Inversly Propertion

#Higher the bill , higher the tip from given data
#Higher the size of people , higher the tip

#But Total bill makes high change in tip than size of people
df
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df)
# Out:
# <Axes: >
