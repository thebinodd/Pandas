# %%
import pandas as pd

# %%
data = pd.read_csv("deliveries.csv")

# %%
batsman = data.groupby("batsman")
batsman

# %%
batsman["batsman_runs"].sum().sort_values(ascending=False)
# Out:
# batsman
# SK Raina        4548
# V Kohli         4423
# RG Sharma       4207
# G Gambhir       4132
# DA Warner       4014
#                 ...
# RR Bhatkal         0
# M Ashwin           0
# Abdur Razzak       0
# IC Pandey          0
# Sunny Gupta        0
# Name: batsman_runs, Length: 461, dtype: int64

# %%
mask = data["batsman_runs"] == 6
newData = data[mask]
newData.groupby("batsman").size().sort_values(ascending=False).head()
# Out:
# batsman
# CH Gayle     266
# SK Raina     174
# RG Sharma    173
# DA Warner    160
# V Kohli      160
# dtype: int64

# %%
maskVirat = data["batsman"] == "V Kohli"
data[maskVirat].groupby("bowling_team")["batsman_runs"].sum().sort_values(ascending=False).head(3)
# Out:
# bowling_team
# Chennai Super Kings    706
# Delhi Daredevils       661
# Kings XI Punjab        483
# Name: batsman_runs, dtype: int64
