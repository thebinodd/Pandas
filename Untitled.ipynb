# %%
import pandas as pd

# %%
data = pd.read_csv("ipl.csv")

# %%
mySeries = data["winner"].value_counts()
mySeries
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
mySeries["Mumbai Indians"] #Indexing
# Out:
# np.int64(92)

# %%
data["team1"].value_counts() + data["team2"].value_counts() #Addition gives total match played
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %%
#Also we can do all operations of python in series

# %%
data["winner"].value_counts().sort_values(ascending=False) #Sort Series
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
data.sort_values('win_by_runs' , ascending=False)
# Out:
#       id  season       city        date                        team1  \
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 613  614    2016    Kolkata  2016-05-08        Kolkata Knight Riders
# 6      7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.sort_values(['win_by_runs' , 'win_by_wickets'] , ascending=[False, False])
