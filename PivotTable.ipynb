# %%
import pandas as pd

# %%
data = pd.read_csv("ipl.csv")

# %%
data.pivot_table(index="team1" , columns="team2" , values=["win_by_runs"] , aggfunc=["max"])

#AggFunctions :- mean , count , sum , nunique , min . max ,std , var
#we can give multiple index and columns
# Out:
#                                             max                  \
#                                     win_by_runs
# team2                       Chennai Super Kings Deccan Chargers
# team1
# Chennai Super Kings                         NaN            78.0
# Deccan Chargers                            31.0             NaN
# Delhi Daredevils                            9.0            12.0
# Gujarat Lions                               NaN             NaN
# Kings XI Punjab                            44.0            25.0
# Kochi Tuskers Kerala                        NaN             NaN
# Kolkata Knight Riders                       3.0            24.0
# Mumbai Indians                             60.0            63.0
# Pune Warriors                              24.0             0.0
# Rajasthan Royals                           17.0             2.0
# Rising Pune Supergiant                      NaN             NaN
# Rising Pune Supergiants                     NaN             NaN
# ...
