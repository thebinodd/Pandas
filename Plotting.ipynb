# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ipl.csv")

# %%
decision = data["toss_decision"].value_counts()
decision
# Out:
# toss_decision
# field    363
# bat      273
# Name: count, dtype: int64

# %%
decision.plot(kind="bar")
# Out:
# <Axes: xlabel='toss_decision'>

# %%
decision.plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["winner"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='winner'>

# %%
data.plot(
    kind='scatter',
    x='win_by_runs',
    y='win_by_wickets'
)
# Out:
# <Axes: xlabel='win_by_runs', ylabel='win_by_wickets'>

# %%
pd.crosstab(
    data['toss_winner'],
    data['winner']
)
# Out:
# winner                       Chennai Super Kings  Deccan Chargers  \
# toss_winner
# Chennai Super Kings                           42                1
# Deccan Chargers                                2               19
# Delhi Daredevils                               4                0
# Gujarat Lions                                  0                0
# Kings XI Punjab                                3                2
# Kochi Tuskers Kerala                           0                1
# Kolkata Knight Riders                          6                1
# Mumbai Indians                                 5                0
# Pune Warriors                                  3                0
# Rajasthan Royals                               8                1
# Rising Pune Supergiant                         0                0
# Rising Pune Supergiants                        0                0
# Royal Challengers Bangalore                    3                4
# ...
